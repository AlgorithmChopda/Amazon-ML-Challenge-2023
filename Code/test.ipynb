# %%
import pandas as pd

# %%
train = pd.read_csv(r'D:\Amazon-Hackathon\dataset\dataset-subset.csv')

# %%
train
# Out:
#      PRODUCT_ID                                              TITLE
# 0       1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...  \
# 1       2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2       2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3       1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4        283658  The United Empire Loyalists: A Chronicle of th...
# ..          ...                                                ...
# 995     1997414  Green India Napier grass seeds, Elephant grass...
# 996      219646                  Carranza and His Bolshevik Regime
# 997     2824714  HiEnd Accents Stella Faux Silk Velvet Western ...
# 998     1563344  Lilis Women's Slim 2 Piece Suits Lady Blazer P...
# 999      873661                            Norpro Bamboo Tong, 12"
#
#                                          BULLET_POINTS
# 0    [LUXURIOUS & APPEALING: Beautiful custom-made ...  \
# ...

# %%
col = train['PRODUCT_TYPE_ID'].nunique()

# %%
col
# Out:
# 563

# %%
count = train['PRODUCT_TYPE_ID'].value_counts()

# %%
count
# Out:
# PRODUCT_TYPE_ID
# 1        45
# 12064    24
# 0        22
# 6104     17
# 23       13
#          ..
# 12973     1
# 3036      1
# 6106      1
# 14        1
# 1399      1
# Name: count, Length: 563, dtype: int64

# %%
same = train.loc[train['PRODUCT_LENGTH'] == 600]

# %%
same
# Out:
#      PRODUCT_ID                                              TITLE
# 13      1991694  Mediterranean diet for beginners: 7Benefits of...  \
# 40       213498  Twin Flame Book of Positive Affirmations: Soul...
# 71       331813  Say Something Dirty to 45 Friends, Lovers, and...
# 87      1325580  Wacoal Women's Body By Wacoal Underwire Bra (3...
# 102      415284                                   Paul Clifford: 3
# ..          ...                                                ...
# 926      515106  EL LIBRO MÁGICO (Versión sin ilustrar): #1 Los...
# 937     1890479                 La taxista: relato erótico lésbico
# 959      475074                               But Mom, I'm a Ninja
# 981      217464  The Common Good and the Global Emergency: God ...
# 993      197953  Time Tells All: Premium Large Print Hardcover ...
#
#     BULLET_POINTS                                        DESCRIPTION
# 13            NaN                                                NaN  \
# ...

# %%
col = ['PRODUCT_ID', 'TITLE', 'BULLET_POINTS', 'DESCRIPTION', 'PRODUCT_TYPE_ID', 'PRODUCT_LENGTH']

# %%
col
# Out:
# ['PRODUCT_ID',
#  'TITLE',
#  'BULLET_POINTS',
#  'DESCRIPTION',
#  'PRODUCT_TYPE_ID',
#  'PRODUCT_LENGTH']

# %%
# lower casing the values

for c in ['TITLE', 'BULLET_POINTS', 'DESCRIPTION'] :
    train[c] = train[c].str.lower()

# %%
train
# Out:
#      PRODUCT_ID                                              TITLE
# 0       1925202  artzfolio tulip flowers blackout curtain for d...  \
# 1       2673191  marks & spencer girls' pyjama sets t86_2561c_n...
# 2       2765088  priknik horn red electric air horn compressor ...
# 3       1594019  alishah women's cotton ankle length leggings c...
# 4        283658  the united empire loyalists: a chronicle of th...
# ..          ...                                                ...
# 995     1997414  green india napier grass seeds, elephant grass...
# 996      219646                  carranza and his bolshevik regime
# 997     2824714  hiend accents stella faux silk velvet western ...
# 998     1563344  lilis women's slim 2 piece suits lady blazer p...
# 999      873661                            norpro bamboo tong, 12"
#
#                                          BULLET_POINTS
# 0    [luxurious & appealing: beautiful custom-made ...  \
# ...

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# ...
#
# ...
#                                               0.0/12.2 MB ? eta -:--:--
#                                               0.0/12.2 MB 1.4 MB/s eta 0:00:09
#                                               0.0/12.2 MB 1.4 MB/s eta 0:00:09
#                                               0.0/12.2 MB 1.4 MB/s eta 0:00:09
#                                               0.0/12.2 MB 1.4 MB/s eta 0:00:09
#                                              0.1/12.2 MB 350.1 kB/s eta 0:00:35
#                                              0.1/12.2 MB 364.4 kB/s eta 0:00:34
#                                              0.2/12.2 MB 468.3 kB/s eta 0:00:26
#                                              0.2/12.2 MB 491.5 kB/s eta 0:00:25
#                                              0.3/12.2 MB 703.7 kB/s eta 0:00:17
#      -                                       0.4/12.2 MB 809.6 kB/s eta 0:00:15
#      -                                       0.5/12.2 MB 954.4 kB/s eta 0:00:13
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string
import spacy
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vinay
# [nltk_data]     Chopda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Vinay
# [nltk_data]     Chopda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
def cleanText(text):    
    
    if not text:
        return ""
    if type(text) == float:
        return ""
    
    # Tokenization
    tokens = word_tokenize(text)

    # Lowercasing
    tokens = [token.lower() for token in tokens]

    # Removing Punctuation
    tokens = [token for token in tokens if token not in string.punctuation]

    # Removing Stop Words
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    # Stemming
    ps = PorterStemmer()
    tokens = [ps.stem(token) for token in tokens]

    # Lemmatization
    # nlp = spacy.load('en_core_web_sm')
    # tokens = [nlp(token)[0].lemma_ for token in tokens]

    # Final Cleaned Text
    cleaned_text = ' '.join(tokens)
    
    return cleaned_text

# %%
for c in ['TITLE', 'BULLET_POINTS', 'DESCRIPTION'] :
    train[c] = train[c].apply(lambda x: cleanText(x))

# %%
train
# Out:
#      PRODUCT_ID                                              TITLE
# 0       1925202  artzfolio tulip flower blackout curtain door w...  \
# 1       2673191  mark spencer girl pyjama set t86_2561c_navi mi...
# 2       2765088  priknik horn red electr air horn compressor in...
# 3       1594019  alishah women 's cotton ankl length leg combo ...
# 4        283658          unit empir loyalist chronicl great migrat
# ..          ...                                                ...
# 995     1997414  green india napier grass seed eleph grass seed...
# 996      219646                           carranza bolshevik regim
# 997     2824714  hiend accent stella faux silk velvet western f...
# 998     1563344  lili women 's slim 2 piec suit ladi blazer pan...
# 999      873661                           norpro bamboo tong 12 ``
#
#                                          BULLET_POINTS
# 0    luxuri appeal beauti custom-mad curtain decor ...  \
# ...

# %%
pip install sklearn
# Out:
# ...
#
#   Using cached sklearn-0.0.post4.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [10 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\Vinay Chopda\AppData\Local\Temp\pip-install-z6c4pkjs\sklearn_8b6cfd27470941739cf84527672f1afd\setup.py", line 10, in <module>
#       LONG_DESCRIPTION = f.read()
#                          ^^^^^^^^
#     File "C:\Users\Vinay Chopda\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#       return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
